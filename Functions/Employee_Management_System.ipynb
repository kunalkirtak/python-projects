# %% [markdown]
# # **Employee Management System**

# %%
# Employee Management System

employees = []


def add_employee():
    emp_id = input("Employee ID: ")
    name = input("Employee Name: ")
    salary = float(input("Salary: ₹"))

    employees.append({
        "id": emp_id,
        "name": name,
        "salary": salary
    })

    print("Employee Added Successfully.")


def view_employees():

    if not employees:
        print("No Employee Records.")
        return

    print("\nEmployee Records")
    print("-" * 40)

    for employee in employees:
        print(
            f"ID: {employee['id']} | "
            f"Name: {employee['name']} | "
            f"Salary: ₹{employee['salary']:.2f}"
        )


def search_employee():

    emp_id = input("Enter Employee ID: ")

    for employee in employees:
        if employee["id"] == emp_id:
            print(employee)
            return

    print("Employee Not Found.")


def update_salary():

    emp_id = input("Employee ID: ")

    for employee in employees:

        if employee["id"] == emp_id:
            employee["salary"] = float(input("New Salary: ₹"))
            print("Salary Updated Successfully.")
            return

    print("Employee Not Found.")


def delete_employee():

    emp_id = input("Employee ID: ")

    for employee in employees:

        if employee["id"] == emp_id:
            employees.remove(employee)
            print("Employee Deleted Successfully.")
            return

    print("Employee Not Found.")


def menu():
    print("\n===== Employee Management System =====")
    print("1. Add Employee")
    print("2. View Employees")
    print("3. Search Employee")
    print("4. Update Salary")
    print("5. Delete Employee")
    print("6. Exit")


while True:

    menu()

    choice = input("Enter Choice: ")

    if choice == "1":
        add_employee()

    elif choice == "2":
        view_employees()

    elif choice == "3":
        search_employee()

    elif choice == "4":
        update_salary()

    elif choice == "5":
        delete_employee()

    elif choice == "6":
        print("Goodbye!")
        break

    else:
        print("Invalid Choice.")
# Out:
# ===== Employee Management System =====
# 1. Add Employee
# 2. View Employees
# 3. Search Employee
# 4. Update Salary
# 5. Delete Employee
# 6. Exit
# Enter Choice: 1
# Employee ID: 123
# Employee Name: Ram
# Salary: ₹5000
# Employee Added Successfully.
#
# ===== Employee Management System =====
# 1. Add Employee
# 2. View Employees
# 3. Search Employee
# 4. Update Salary
# 5. Delete Employee
# 6. Exit
# Enter Choice: 1
# Employee ID: 124
# Employee Name: Atul
# Salary: ₹9550
# Employee Added Successfully.
#
# ===== Employee Management System =====
# 1. Add Employee
# 2. View Employees
# 3. Search Employee
# 4. Update Salary
# 5. Delete Employee
# 6. Exit
# Enter Choice: 1
# Employee ID: 125
# Employee Name: Sita
# Salary: ₹9999
# Employee Added Successfully.
#
# ===== Employee Management System =====
# 1. Add Employee
# 2. View Employees
# 3. Search Employee
# 4. Update Salary
# 5. Delete Employee
# 6. Exit
# Enter Choice: 2
#
# Employee Records
# ----------------------------------------
# ID: 123 | Name: Ram | Salary: ₹5000.00
# ID: 124 | Name: Atul | Salary: ₹9550.00
# ID: 125 | Name: Sita | Salary: ₹9999.00
#
# ===== Employee Management System =====
# 1. Add Employee
# 2. View Employees
# 3. Search Employee
# 4. Update Salary
# 5. Delete Employee
# 6. Exit
# Enter Choice: 3
# Enter Employee ID: 123
# {'id': '123', 'name': 'Ram', 'salary': 5000.0}
#
# ===== Employee Management System =====
# 1. Add Employee
# 2. View Employees
# 3. Search Employee
# 4. Update Salary
# 5. Delete Employee
# 6. Exit
# Enter Choice: 4
# Employee ID: 123
# New Salary: ₹9551
# Salary Updated Successfully.
#
# ===== Employee Management System =====
# 1. Add Employee
# 2. View Employees
# 3. Search Employee
# 4. Update Salary
# 5. Delete Employee
# 6. Exit
# Enter Choice: 2
#
# Employee Records
# ----------------------------------------
# ID: 123 | Name: Ram | Salary: ₹9551.00
# ID: 124 | Name: Atul | Salary: ₹9550.00
# ID: 125 | Name: Sita | Salary: ₹9999.00
#
# ===== Employee Management System =====
# 1. Add Employee
# 2. View Employees
# 3. Search Employee
# 4. Update Salary
# 5. Delete Employee
# 6. Exit
# Enter Choice: 5
# Employee ID: 123
# Employee Deleted Successfully.
#
# ===== Employee Management System =====
# 1. Add Employee
# 2. View Employees
# 3. Search Employee
# 4. Update Salary
# 5. Delete Employee
# 6. Exit
# Enter Choice: 2
#
# Employee Records
# ----------------------------------------
# ID: 124 | Name: Atul | Salary: ₹9550.00
# ID: 125 | Name: Sita | Salary: ₹9999.00
#
# ===== Employee Management System =====
# 1. Add Employee
# 2. View Employees
# 3. Search Employee
# 4. Update Salary
# 5. Delete Employee
# 6. Exit
# Enter Choice: 6
# Goodbye!
