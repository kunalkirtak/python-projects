# %% [markdown]
# # **User Model**

# %%
pip install 'pydantic[email]'
# Out:
# Requirement already satisfied: pydantic[email] in /usr/local/lib/python3.12/dist-packages (2.13.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic[email]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic[email]) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic[email]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic[email]) (0.4.2)
# Collecting email-validator>=2.0.0 (from pydantic[email])
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->pydantic[email])
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->pydantic[email]) (3.18)
# Downloading email_validator-2.3.0-py3-none-any.whl (35 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 9.0 MB/s eta 0:00:00
# Installing collected packages: dnspython, email-validator
# Successfully installed dnspython-2.8.0 email-validator-2.3.0

# %%
"""
==========================================================
 User Model using Pydantic
==========================================================
"""

from pydantic import BaseModel, Field, EmailStr, ValidationError


class User(BaseModel):
    username: str = Field(min_length=3, max_length=20)
    email: EmailStr
    age: int = Field(ge=18, le=100)
    phone: str = Field(pattern=r"^[6-9]\d{9}$")
    password: str = Field(min_length=8)


print("=" * 60)
print("USER MODEL")
print("=" * 60)

try:

    user = User(
        username="kunal",
        email="kunal@example.com",
        age=23,
        phone="9876543210",
        password="StrongPass123"
    )

    print(user)

    print("\nDictionary Representation")
    print(user.model_dump())

    print("\nJSON Representation")
    print(user.model_dump_json(indent=4))

except ValidationError as error:

    print(error)
# Out:
# ============================================================
# USER MODEL
# ============================================================
# username='kunal' email='kunal@example.com' age=23 phone='9876543210' password='StrongPass123'
#
# Dictionary Representation
# {'username': 'kunal', 'email': 'kunal@example.com', 'age': 23, 'phone': '9876543210', 'password': 'StrongPass123'}
#
# JSON Representation
# {
#     "username": "kunal",
#     "email": "kunal@example.com",
#     "age": 23,
#     "phone": "9876543210",
#     "password": "StrongPass123"
# }
