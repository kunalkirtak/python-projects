# %% [markdown]
# # **EMI Calculator**

# %%
# EMI Calculator

print("=" * 40)
print("EMI Calculator")
print("=" * 40)

principal = float(input("Loan Amount (₹): "))

annual_rate = float(input("Annual Interest Rate (%): "))

years = int(input("Loan Duration (Years): "))

monthly_rate = annual_rate / (12 * 100)

months = years * 12

emi = (
    principal
    * monthly_rate
    * (1 + monthly_rate) ** months
) / (
    (1 + monthly_rate) ** months - 1
)

total_payment = emi * months

total_interest = total_payment - principal

print("\n------ EMI Details ------")
print(f"Monthly EMI      : ₹{emi:.2f}")
print(f"Total Payment    : ₹{total_payment:.2f}")
print(f"Total Interest   : ₹{total_interest:.2f}")
# Out:
# ========================================
# EMI Calculator
# ========================================
# Loan Amount (₹): 100000
# Annual Interest Rate (%): 5
# Loan Duration (Years): 2
#
# ------ EMI Details ------
# Monthly EMI      : ₹4387.14
# Total Payment    : ₹105291.34
# Total Interest   : ₹5291.34

# %%
print("=" * 40)
print("EMI Calculator")
print("=" * 40)

principal = float(input("Loan Amount (₹): "))

annual_rate = float(input("Annual Interest Rate (%): "))

years = int(input("Loan Duration (Years): "))

monthly_rate = annual_rate / (12 * 100)

months = years * 12

emi = (
    principal
    * monthly_rate
    * (1 + monthly_rate) ** months
) / (
    (1 + monthly_rate) ** months - 1
)

total_payment = emi * months

total_interest = total_payment - principal

print("\n------ EMI Details ------")
print(f"Monthly EMI      : ₹{emi:.2f}")
print(f"Total Payment    : ₹{total_payment:.2f}")
print(f"Total Interest   : ₹{total_interest:.2f}")
# Out:
# ========================================
# EMI Calculator
# ========================================
# Loan Amount (₹): 500000
# Annual Interest Rate (%): 7
# Loan Duration (Years): 2
#
# ------ EMI Details ------
# Monthly EMI      : ₹22386.29
# Total Payment    : ₹537270.95
# Total Interest   : ₹37270.95
