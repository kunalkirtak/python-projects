# %% [markdown]
# # **Text Analyzer**

# %%
# ==========================================
# Text Analyzer
# ==========================================

print("=" * 40)
print("Text Analyzer")
print("=" * 40)

text = input("Enter a sentence:\n")

characters = len(text)
characters_without_spaces = len(text.replace(" ", ""))

words = len(text.split())

vowels = 0
consonants = 0
digits = 0
spaces = 0
uppercase = 0
lowercase = 0

for char in text:

    if char.lower() in "aeiou":
        vowels += 1

    elif char.isalpha():
        consonants += 1

    if char.isdigit():
        digits += 1

    if char == " ":
        spaces += 1

    if char.isupper():
        uppercase += 1

    if char.islower():
        lowercase += 1

print("\nText Analysis")
print("-" * 35)

print(f"Total Characters            : {characters}")
print(f"Characters (No Spaces)      : {characters_without_spaces}")
print(f"Total Words                 : {words}")
print(f"Vowels                      : {vowels}")
print(f"Consonants                  : {consonants}")
print(f"Digits                      : {digits}")
print(f"Spaces                      : {spaces}")
print(f"Uppercase Letters           : {uppercase}")
print(f"Lowercase Letters           : {lowercase}")
# Out:
# ========================================
# Text Analyzer
# ========================================
# Enter a sentence:
# Hi I am an AIML Engineer
#
# Text Analysis
# -----------------------------------
# Total Characters            : 24
# Characters (No Spaces)      : 19
# Total Words                 : 6
# Vowels                      : 10
# Consonants                  : 9
# Digits                      : 0
# Spaces                      : 5
# Uppercase Letters           : 7
# Lowercase Letters           : 12

# %%
# ==========================================
# Text Analyzer
# ==========================================

print("=" * 40)
print("Text Analyzer")
print("=" * 40)

text = input("Enter a sentence:\n")

characters = len(text)
characters_without_spaces = len(text.replace(" ", ""))

words = len(text.split())

vowels = 0
consonants = 0
digits = 0
spaces = 0
uppercase = 0
lowercase = 0

for char in text:

    if char.lower() in "aeiou":
        vowels += 1

    elif char.isalpha():
        consonants += 1

    if char.isdigit():
        digits += 1

    if char == " ":
        spaces += 1

    if char.isupper():
        uppercase += 1

    if char.islower():
        lowercase += 1

print("\nText Analysis")
print("-" * 35)

print(f"Total Characters            : {characters}")
print(f"Characters (No Spaces)      : {characters_without_spaces}")
print(f"Total Words                 : {words}")
print(f"Vowels                      : {vowels}")
print(f"Consonants                  : {consonants}")
print(f"Digits                      : {digits}")
print(f"Spaces                      : {spaces}")
print(f"Uppercase Letters           : {uppercase}")
print(f"Lowercase Letters           : {lowercase}")
# Out:
# ========================================
# Text Analyzer
# ========================================
# Enter a sentence:
# Hello, Welcome to our new Office.
#
# Text Analysis
# -----------------------------------
# Total Characters            : 34
# Characters (No Spaces)      : 28
# Total Words                 : 6
# Vowels                      : 12
# Consonants                  : 14
# Digits                      : 0
# Spaces                      : 6
# Uppercase Letters           : 3
# Lowercase Letters           : 23
