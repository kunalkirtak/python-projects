# %% [markdown]
# # **Email Validator**

# %%
# ==========================================
# Email Validator
# ==========================================

print("=" * 40)
print("Email Validator")
print("=" * 40)

email = input("Enter your email address: ").strip()

valid = True

if email.count("@") != 1:
    valid = False

elif email.startswith("@") or email.endswith("@"):
    valid = False

elif "." not in email.split("@")[1]:
    valid = False

elif " " in email:
    valid = False

elif email.endswith("."):
    valid = False

print("\nValidation Result")
print("-" * 30)

if valid:
    print("Valid Email Address")
else:
    print("Invalid Email Address")
# Out:
# ========================================
# Email Validator
# ========================================
# Enter your email address: abcd@gmail.com
#
# Validation Result
# ------------------------------
# Valid Email Address

# %%
# ==========================================
# Email Validator
# ==========================================

print("=" * 40)
print("Email Validator")
print("=" * 40)

email = input("Enter your email address: ").strip()

valid = True

if email.count("@") != 1:
    valid = False

elif email.startswith("@") or email.endswith("@"):
    valid = False

elif "." not in email.split("@")[1]:
    valid = False

elif " " in email:
    valid = False

elif email.endswith("."):
    valid = False

print("\nValidation Result")
print("-" * 30)

if valid:
    print("Valid Email Address")
else:
    print("Invalid Email Address")
# Out:
# ========================================
# Email Validator
# ========================================
# Enter your email address: abklc_gmail
#
# Validation Result
# ------------------------------
# Invalid Email Address
